# %%
import openai

# %%
from openai import OpenAI

# %%
client = OpenAI(
    api_key="04K48DsYPmJyFaxtBOB5r2G9gsCJoMJo",
    base_url="https://api.mistral.ai/v1" 
)

# %%
import os

# %%
os.environ
# Out:
# environ{'USER': 'nicolasd',
#         'VSCODE_WSL_EXT_LOCATION': '/mnt/c/Users/Nicolas/.vscode/extensions/ms-vscode-remote.remote-wsl-0.99.0',
#         'SHLVL': '1',
#         'HOME': '/home/nicolas',
#         'OLDPWD': '/mnt/c/Users/Nicolas/AppData/Local/Programs/Microsoft VS Code',
#         'WSL_DISTRO_NAME': 'UbuntuD',
#         'WAYLAND_DISPLAY': 'wayland-0',
#         'LOGNAME': 'nicolasd',
#         'PULSE_SERVER': 'unix:/mnt/wslg/PulseServer',
#         'WSL_INTEROP': '/run/WSL/4330_interop',
#         'NAME': 'Code',
#         '_': '/home/nicolas/llm_cv_advisor/venv/bin/python',
#         'TERM': 'xterm-color',
#         'PATH': '/home/nicolas/llm_cv_advisor/venv/bin:/home/nicolas/.vscode-server/bin/19e0f9e681ecb8e5c09d8784acaa601316ca4571/bin/remote-cli:/home/nicolas/miniconda3/bin:/home/nicolas/miniconda3/condabin:/usr/local/go/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/usr/games:/usr/local/games:/usr/lib/wsl/lib:/mnt/c/Program Files/WindowsApps/MicrosoftCorporationII.WindowsSubsystemForLinux_2.3.26.0_x64__8wekyb3d8bbwe:/mnt/c/Users/Nicolas/AppData/Local/Programs/Python/Python313/Scripts:/mnt/c/Users/Nicolas/AppData/Local/Programs/Python/Python313:/mnt/c/Program Files/Python39/Scripts:/mnt/c/Program Files/Python39:/mnt/c/Program Files (x86)/Common Files/Oracle/Java/java8path:/mnt/c/Program Files (x86)/Common Files/Oracle/Java/javapath:/mnt/c/WINDOWS/system32:/mnt/c/WINDOWS:/mnt/c/WINDOWS/System32/Wbem:/mnt/c/WINDOWS/System32/WindowsPowerShell/v1.0:/mnt/c/WINDOWS/System32/OpenSSH:/mnt/c/Program Files/nodejs:/mnt/c/ProgramData/chocolatey/bin:/mnt/c/Program Files/Git/cmd:/mnt/c/Users/Nicolas/AppData/Local/Programs/Python/Python312/Scripts:/mnt/c/Users/Nicolas/AppData/Local/Programs/Python/Python312:/mnt/c/Users/Nicolas/AppData/Local/Programs/Python:/mnt/c/Users/Nicolas/AppData/Local/Programs/Python/Python313/Scripts:/mnt/c/Users/Nicolas/AppData/Local/Programs/Python/Python313:/mnt/c/Users/Nicolas/AppData/Local/Programs/Python/Launcher:/mnt/c/Users/Nicolas/AppData/Local/Microsoft/WindowsApps:/mnt/c/Users/Nicolas/AppData/Local/Programs/Microsoft VS Code/bin:/mnt/c/Users/Nicolas/AppData/Roaming/Python/Python39/Scripts:/mnt/c/users/nicolas/projects/ml_lol/venv/lib/site-packages:/mnt/c/Users/Nicolas/AppData/Roaming/npm:/mnt/c/Users/Nicolas/.fly/bin',
#         'XDG_RUNTIME_DIR': '/mnt/wslg/runtime-dir',
#         'DISPLAY': ':0',
#         'LANG': 'C.UTF-8',
#         'SHELL': '/usr/bin/zsh',
#         'PWD': '/mnt/c/Users/Nicolas/AppData/Local/Programs/Microsoft VS Code',
#         'HOSTTYPE': 'x86_64',
#         'WSL2_GUI_APPS_ENABLED': '1',
#         'WSLENV': 'ELECTRON_RUN_AS_NODE/w:',
#         'VSCODE_CWD': '/mnt/c/Users/Nicolas/AppData/Local/Programs/Microsoft VS Code',
#         'VSCODE_NLS_CONFIG': '{"userLocale":"en","osLocale":"en","resolvedLanguage":"en","defaultMessagesFile":"/home/nicolas/.vscode-server/bin/19e0f9e681ecb8e5c09d8784acaa601316ca4571/out/nls.messages.json","locale":"en","availableLanguages":{}}',
#         'VSCODE_HANDLES_SIGPIPE': 'true',
#         'ZSH': '/home/nicolas/.oh-my-zsh',
#         'PAGER': 'cat',
#         'LESS': '-R',
#         'LSCOLORS': 'Gxfxcxdxbxegedabagacad',
#         'LS_COLORS': 'rs=0:di=01;34:ln=01;36:mh=00:pi=40;33:so=01;35:do=01;35:bd=40;33;01:cd=40;33;01:or=40;31;01:mi=00:su=37;41:sg=30;43:ca=00:tw=30;42:ow=34;42:st=37;44:ex=01;32:*.tar=01;31:*.tgz=01;31:*.arc=01;31:*.arj=01;31:*.taz=01;31:*.lha=01;31:*.lz4=01;31:*.lzh=01;31:*.lzma=01;31:*.tlz=01;31:*.txz=01;31:*.tzo=01;31:*.t7z=01;31:*.zip=01;31:*.z=01;31:*.dz=01;31:*.gz=01;31:*.lrz=01;31:*.lz=01;31:*.lzo=01;31:*.xz=01;31:*.zst=01;31:*.tzst=01;31:*.bz2=01;31:*.bz=01;31:*.tbz=01;31:*.tbz2=01;31:*.tz=01;31:*.deb=01;31:*.rpm=01;31:*.jar=01;31:*.war=01;31:*.ear=01;31:*.sar=01;31:*.rar=01;31:*.alz=01;31:*.ace=01;31:*.zoo=01;31:*.cpio=01;31:*.7z=01;31:*.rz=01;31:*.cab=01;31:*.wim=01;31:*.swm=01;31:*.dwm=01;31:*.esd=01;31:*.avif=01;35:*.jpg=01;35:*.jpeg=01;35:*.mjpg=01;35:*.mjpeg=01;35:*.gif=01;35:*.bmp=01;35:*.pbm=01;35:*.pgm=01;35:*.ppm=01;35:*.tga=01;35:*.xbm=01;35:*.xpm=01;35:*.tif=01;35:*.tiff=01;35:*.png=01;35:*.svg=01;35:*.svgz=01;35:*.mng=01;35:*.pcx=01;35:*.mov=01;35:*.mpg=01;35:*.mpeg=01;35:*.m2v=01;35:*.mkv=01;35:*.webm=01;35:*.webp=01;35:*.ogm=01;35:*.mp4=01;35:*.m4v=01;35:*.mp4v=01;35:*.vob=01;35:*.qt=01;35:*.nuv=01;35:*.wmv=01;35:*.asf=01;35:*.rm=01;35:*.rmvb=01;35:*.flc=01;35:*.avi=01;35:*.fli=01;35:*.flv=01;35:*.gl=01;35:*.dl=01;35:*.xcf=01;35:*.xwd=01;35:*.yuv=01;35:*.cgm=01;35:*.emf=01;35:*.ogv=01;35:*.ogx=01;35:*.aac=00;36:*.au=00;36:*.flac=00;36:*.m4a=00;36:*.mid=00;36:*.midi=00;36:*.mka=00;36:*.mp3=00;36:*.mpc=00;36:*.ogg=00;36:*.ra=00;36:*.wav=00;36:*.oga=00;36:*.opus=00;36:*.spx=00;36:*.xspf=00;36:*~=00;90:*#=00;90:*.bak=00;90:*.crdownload=00;90:*.dpkg-dist=00;90:*.dpkg-new=00;90:*.dpkg-old=00;90:*.dpkg-tmp=00;90:*.old=00;90:*.orig=00;90:*.part=00;90:*.rej=00;90:*.rpmnew=00;90:*.rpmorig=00;90:*.rpmsave=00;90:*.swp=00;90:*.tmp=00;90:*.ucf-dist=00;90:*.ucf-new=00;90:*.ucf-old=00;90:',
#         'CONDA_EXE': '/home/nicolas/miniconda3/bin/conda',
#         'CONDA_PYTHON_EXE': '/home/nicolas/miniconda3/bin/python',
#         'CONDA_SHLVL': '1',
#         'CONDA_PREFIX': '/home/nicolas/miniconda3',
#         'CONDA_DEFAULT_ENV': 'base',
#         'CONDA_PROMPT_MODIFIER': '(base) ',
#         'VSCODE_ESM_ENTRYPOINT': 'vs/workbench/api/node/extensionHostProcess',
#         'VSCODE_HANDLES_UNCAUGHT_ERRORS': 'true',
#         'ELECTRON_RUN_AS_NODE': '1',
#         'VSCODE_IPC_HOOK_CLI': '/mnt/wslg/runtime-dir/vscode-ipc-8c7d668d-5d67-4b0b-8639-865f49cbf583.sock',
#         'VSCODE_L10N_BUNDLE_LOCATION': '',
#         'PYTHONUNBUFFERED': '1',
#         'VIRTUAL_ENV': '/home/nicolas/llm_cv_advisor/venv',
#         'PYTHONIOENCODING': 'utf-8',
#         'PS1': '(venv) ',
#         'PYDEVD_IPYTHON_COMPATIBLE_DEBUGGING': '1',
#         'PYTHON_FROZEN_MODULES': 'on',
#         'PYDEVD_USE_FRAME_EVAL': 'NO',
#         'CLICOLOR': '1',
#         'FORCE_COLOR': '1',
#         'CLICOLOR_FORCE': '1',
#         'GIT_PAGER': 'cat',
#         'MPLBACKEND': 'module://matplotlib_inline.backend_inline'}

# %%
response = client.chat.completions.create(
    model='mistral-medium',
    messages=[{"role": "user", "content": "é muito tarde para arrumar o Curriculo?"}]
)

# %%
response.choices[0].message.content
# Out:
# 'Não, nunca é tarde demais para arrumar o seu currículo. Independentemente da hora ou do dia, você pode dedicar algum tempo para revisar e melhorar o seu currículo sempre que quiser. Além disso, lembre-se de que o seu currículo é um documento vivo que deve ser atualizado regularmente para refletir seu crescimento profissional e habilidades recém-adquiridas. Portanto, não há uma hora ou um dia específicos para arrumar o seu currículo. Você pode fazê-lo sempre que sentir que precisa.'
